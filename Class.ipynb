# %% [markdown]
# <a href="https://colab.research.google.com/github/wordsbyanmol/PUS2024_AArora/blob/main/Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# !pip install python3-rtree
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# ERROR: Could not find a version that satisfies the requirement python3-rtree (from versions: none)
# ERROR: No matching distribution found for python3-rtree

# %%
import pandas as pd
import numpy as np

# %%
#shapely
import geopandas as gpd
gpd.datasets.available
# Out:
# []

# %%
url= "https://github.com/nvkelso/natural-earth-vector/raw/refs/heads/master/110m_cultural/ne_110m_admin_0_countries.shp"

# %%
world= gpd.read_file(url)

# %%
world. head ()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE TLC                        ADMIN  ...  \
# 0         0      2  Sovereign country   1                         Fiji  ...
# 1         0      2  Sovereign country   1  United Republic of Tanzania  ...
# 2         0      2      Indeterminate   1               Western Sahara  ...
# 3         0      2  Sovereign country   1                       Canada  ...
# 4         1      2            Country   1     United States of America  ...
#
#       FCLASS_TR     FCLASS_ID     FCLASS_PL FCLASS_GR  FCLASS_IT  \
# 0          None          None          None      None       None
# 1          None          None          None      None       None
# 2  Unrecognized  Unrecognized  Unrecognized      None       None
# 3          None          None          None      None       None
# 4          None          None          None      None       None
#
#       FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 0          None      None       None      None
# 1          None      None       None      None
# 2  Unrecognized      None       None      None
# 3          None      None       None      None
# 4          None      None       None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((180 -16.06713, 180 -16.55522, ...
# 1  POLYGON ((33.90371 -0.95, 34.07262 -1.05982, 3...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84 49, -122.97421 49.0025...
# 4  MULTIPOLYGON (((-122.84 49, -120 49, -117.0312...
#
# [5 rows x 169 columns]

# %%
world.iloc[0]
# Out:
# featurecla                                      Admin-0 country
# scalerank                                                     1
# LABELRANK                                                     6
# SOVEREIGNT                                                 Fiji
# SOV_A3                                                      FJI
#                                     ...
# FCLASS_NL                                                  None
# FCLASS_SE                                                  None
# FCLASS_BD                                                  None
# FCLASS_UA                                                  None
# geometry      MULTIPOLYGON (((180 -16.067132663642447, 180 -...
# Name: 0, Length: 169, dtype: object

# %%
world.iloc[:,0]
# Out:
# 0      Admin-0 country
# 1      Admin-0 country
# 2      Admin-0 country
# 3      Admin-0 country
# 4      Admin-0 country
#             ...
# 172    Admin-0 country
# 173    Admin-0 country
# 174    Admin-0 country
# 175    Admin-0 country
# 176    Admin-0 country
# Name: featurecla, Length: 177, dtype: object

# %%
world.head ()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE TLC                        ADMIN  ...  \
# 0         0      2  Sovereign country   1                         Fiji  ...
# 1         0      2  Sovereign country   1  United Republic of Tanzania  ...
# 2         0      2      Indeterminate   1               Western Sahara  ...
# 3         0      2  Sovereign country   1                       Canada  ...
# 4         1      2            Country   1     United States of America  ...
#
#       FCLASS_TR     FCLASS_ID     FCLASS_PL FCLASS_GR  FCLASS_IT  \
# 0          None          None          None      None       None
# 1          None          None          None      None       None
# 2  Unrecognized  Unrecognized  Unrecognized      None       None
# 3          None          None          None      None       None
# 4          None          None          None      None       None
#
#       FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 0          None      None       None      None
# 1          None      None       None      None
# 2  Unrecognized      None       None      None
# 3          None      None       None      None
# 4          None      None       None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((180 -16.06713, 180 -16.55522, ...
# 1  POLYGON ((33.90371 -0.95, 34.07262 -1.05982, 3...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84 49, -122.97421 49.0025...
# 4  MULTIPOLYGON (((-122.84 49, -120 49, -117.0312...
#
# [5 rows x 169 columns]

# %%
world.columns
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'TLC', 'ADMIN',
#        ...
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype='object', length=169)

# %%
world.iloc[0].loc["geometry"]
# Out:
# <MULTIPOLYGON (((180 -16.067, 180 -16.555, 179.364 -16.801, 178.725 -17.012,...>

# %%
world.iloc[3].loc["geometry"]
# Out:
# <MULTIPOLYGON (((-122.84 49, -122.974 49.003, -124.91 49.985, -125.625 50.41...>

# %%
world.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Columns: 169 entries, featurecla to geometry
# dtypes: float64(6), geometry(1), int32(24), int64(1), object(137)
# memory usage: 217.2+ KB

# %%
world.tail()
# Out:
#           featurecla  scalerank  LABELRANK           SOVEREIGNT SOV_A3  \
# 172  Admin-0 country          1          5   Republic of Serbia    SRB
# 173  Admin-0 country          1          6           Montenegro    MNE
# 174  Admin-0 country          1          6               Kosovo    KOS
# 175  Admin-0 country          1          5  Trinidad and Tobago    TTO
# 176  Admin-0 country          1          3          South Sudan    SDS
#
#      ADM0_DIF  LEVEL               TYPE TLC                ADMIN  ...  \
# 172         0      2  Sovereign country   1   Republic of Serbia  ...
# 173         0      2  Sovereign country   1           Montenegro  ...
# 174         0      2           Disputed   1               Kosovo  ...
# 175         0      2  Sovereign country   1  Trinidad and Tobago  ...
# 176         0      2  Sovereign country   1          South Sudan  ...
#
#            FCLASS_TR     FCLASS_ID        FCLASS_PL     FCLASS_GR  \
# 172             None          None             None          None
# 173             None          None             None          None
# 174  Admin-0 country  Unrecognized  Admin-0 country  Unrecognized
# 175             None          None             None          None
# 176             None          None             None          None
#
#            FCLASS_IT        FCLASS_NL        FCLASS_SE        FCLASS_BD  \
# 172             None             None             None             None
# 173             None             None             None             None
# 174  Admin-0 country  Admin-0 country  Admin-0 country  Admin-0 country
# 175             None             None             None             None
# 176             None             None             None             None
#
#         FCLASS_UA                                           geometry
# 172          None  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173          None  POLYGON ((20.0707 42.58863, 19.80161 42.50009,...
# 174  Unrecognized  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175          None  POLYGON ((-61.68 10.76, -61.105 10.89, -60.895...
# 176          None  POLYGON ((30.83385 3.50917, 29.9535 4.1737, 29...
#
# [5 rows x 169 columns]

# %%
world= world[["POP_EST", "CONTINENT", "ISO_A3", "NAME", "GDP_MD", "geometry"]]

# %%
world.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world.plot()
# Out:
# <Axes: >

# %%
world.head()
# Out:
#        POP_EST      CONTINENT ISO_A3                      NAME    GDP_MD  \
# 0     889953.0        Oceania    FJI                      Fiji      5496
# 1   58005463.0         Africa    TZA                  Tanzania     63177
# 2     603253.0         Africa    ESH                 W. Sahara       907
# 3   37589262.0  North America    CAN                    Canada   1736425
# 4  328239523.0  North America    USA  United States of America  21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180 -16.06713, 180 -16.55522, ...
# 1  POLYGON ((33.90371 -0.95, 34.07262 -1.05982, 3...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84 49, -122.97421 49.0025...
# 4  MULTIPOLYGON (((-122.84 49, -120 49, -117.0312...

# %%
world.dissolve(by="CONTINENT")
# Out:
#                                                                   geometry  \
# CONTINENT
# Africa                   MULTIPOLYGON (((-11.43878 6.78592, -11.70819 6...
# Antarctica               MULTIPOLYGON (((-61.13898 -79.98137, -60.61012...
# Asia                     MULTIPOLYGON (((48.67923 14.0032, 48.23895 13....
# Europe                   MULTIPOLYGON (((-53.55484 2.3349, -53.77852 2....
# North America            MULTIPOLYGON (((-155.22217 19.23972, -155.5421...
# Oceania                  MULTIPOLYGON (((147.91405 -43.21152, 147.56456...
# Seven seas (open ocean)  POLYGON ((68.935 -48.625, 69.58 -48.94, 70.525...
# South America            MULTIPOLYGON (((-68.63999 -55.58002, -69.2321 ...
#
#                              POP_EST ISO_A3                    NAME   GDP_MD
# CONTINENT
# Africa                    58005463.0    TZA                Tanzania    63177
# Antarctica                    4490.0    ATA              Antarctica      898
# Asia                      18513930.0    KAZ              Kazakhstan   181665
# Europe                   144373535.0    RUS                  Russia  1699876
# North America             37589262.0    CAN                  Canada  1736425
# Oceania                     889953.0    FJI                    Fiji     5496
# Seven seas (open ocean)        140.0    ATF  Fr. S. Antarctic Lands       16
# South America             44938712.0    ARG               Argentina   445445

# %%
world.dissolve(by="CONTINENT").plot()
# Out:
# <Axes: >

# %%
world.plot ()
# Out:
# <Axes: >

# %%
ax= world.plot ()
ax.set_title("World WCS 84")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
# Out:
# Text(35.597222222222214, 0.5, 'Latitude')

# %%
world.t0_crs("EPSG:3395").plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-802d761a4dfd> in <cell line: 1>()
# ----> 1 world.t0_crs("EPSG:3395").plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'GeoDataFrame' object has no attribute 't0_crs'

# %%
# worlds_nopoles= world[(world.NAME != "Antarctica")] & (world.NAME != "Fr. S. "AnTARCTIC lANDS")]

# %%
ax= world_nopoles[world.NAME == "cHINE"].to_crs("epsg=3407").crs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-558b1e4b5ffc> in <cell line: 1>()
# ----> 1 ax= world_nopoles[world.NAME == "cHINE"].to_crs("epsg=3407").crs
#
# NameError: name 'world_nopoles' is not defined

# %%
world[world.NAME== "India"]. plot ()
# Out:
# <Axes: >

# %%
world[world.NAME== "India", "geopmetry"]. plot ()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# Name: NAME, Length: 177, dtype: bool, 'geopmetry')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-44-7199018988b0> in <cell line: 1>()
# ----> 1 world[world.NAME== "India", "geopmetry"]. plot ()
#
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py in __getitem__(self, key)
#    1748         return a GeoDataFrame.
#    1749         """
# -> 1750         result = super().__getitem__(key)
#    1751         # Custom logic to avoid waiting for pandas GH51895
#    1752         # result is not geometry dtype for multi-indexes
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3815             #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816             #  the TypeError.
# -> 3817             self._check_indexing_error(key)
#    3818             raise
#    3819
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _check_indexing_error(self, key)
#    6057             # if key is not a scalar, directly raise an error (the code below
#    6058             # would convert to numpy arrays and raise later any way) - GH29926
# -> 6059             raise InvalidIndexError(key)
#    6060
#    6061     @cache_readonly
#
# InvalidIndexError: (0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# Name: NAME, Length: 177, dtype: bool, 'geopmetry')

# %%
world.set_index("NAME", inplace=True)

# %%
type(world.loc["Italy", "geometry"])
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
url = "https://www2.census.gov/geo/tiger/TIGER2024/UAC20/tl_2024_us_uac20.zip"

# %%
cities= gpd.read_file(url)

# %%
cities
# Out:
#      UACE20 GEOID20       GEOIDFQ20                    NAME20  \
# 0     14482   14482  400C200US14482                Casper, WY
# 1     81604   81604  400C200US81604              Sheridan, WY
# 2     18397   18397  400C200US18397                  Cody, WY
# 3     89488   89488  400C200US89488                 Union, SC
# 4     01684   01684  400C200US01684                Alpena, MI
# ...     ...     ...             ...                       ...
# 2639  34273   34273  400C200US34273        Grand Junction, CO
# 2640  78094   78094  400C200US78094                 Salem, IL
# 2641  91027   91027  400C200US91027                  Waco, TX
# 2642  04033   04033  400C200US04033                Auburn, AL
# 2643  45451   45451  400C200US45451  Kissimmee--St. Cloud, FL
#
#                                NAMELSAD20 LSAD20 MTFCC20 FUNCSTAT20  \
# 0                   Casper, WY Urban Area     67   G3500          S
# 1                 Sheridan, WY Urban Area     67   G3500          S
# 2                     Cody, WY Urban Area     67   G3500          S
# 3                    Union, SC Urban Area     67   G3500          S
# 4                   Alpena, MI Urban Area     67   G3500          S
# ...                                   ...    ...     ...        ...
# 2639        Grand Junction, CO Urban Area     67   G3500          S
# 2640                 Salem, IL Urban Area     67   G3500          S
# 2641                  Waco, TX Urban Area     67   G3500          S
# 2642                Auburn, AL Urban Area     67   G3500          S
# 2643  Kissimmee--St. Cloud, FL Urban Area     67   G3500          S
#
#         ALAND20  AWATER20   INTPTLAT20    INTPTLON20  \
# 0      72213481    859632  +42.8391477  -106.3367071
# 1      33638046     49823  +44.7865750  -106.9619773
# 2      17893069     29888  +44.5246958  -109.0502125
# 3      23763897      8766  +34.7247912  -081.6262933
# 4      32911444   1992202  +45.0495900  -083.4535730
# ...         ...       ...          ...           ...
# 2639  195837116   3556414  +39.0890618  -108.5674520
# 2640   12683024    167909  +38.6257591  -088.9548021
# 2641  232663051   1417906  +31.5415622  -097.1640133
# 2642  158407525   1469728  +32.6113816  -085.4521355
# 2643  418516399  10280685  +28.3072705  -081.3708011
#
#                                                geometry
# 0     MULTIPOLYGON (((-106.27308 42.8288, -106.27308...
# 1     MULTIPOLYGON (((-106.95562 44.82931, -106.9554...
# 2     MULTIPOLYGON (((-109.05647 44.51664, -109.0569...
# 3     MULTIPOLYGON (((-81.59001 34.71101, -81.59056 ...
# 4     MULTIPOLYGON (((-83.40797 45.06554, -83.40832 ...
# ...                                                 ...
# 2639  MULTIPOLYGON (((-108.42236 39.10622, -108.4208...
# 2640  POLYGON ((-88.93604 38.64526, -88.93595 38.645...
# 2641  MULTIPOLYGON (((-97.0998 31.54163, -97.09979 3...
# 2642  MULTIPOLYGON (((-85.43021 32.66315, -85.42986 ...
# 2643  MULTIPOLYGON (((-81.20542 28.25074, -81.20413 ...
#
# [2644 rows x 13 columns]

# %%
ax= worlds_nopoles.plotcities.plot(ax=ax, color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-8569d37c8d77> in <cell line: 1>()
# ----> 1 ax= worlds_nopoles.plotcities.plot(ax=ax, color="red")
#
# NameError: name 'worlds_nopoles' is not defined

# %%
ax= world_nopoles.plot()
cities.to_crs(world_nopoles.crs).plot (ax=ax, color= "red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-610761311f87> in <cell line: 1>()
# ----> 1 ax= world_nopoles.plot()
#       2 cities.to_crs(world_nopoles.crs).plot (ax=ax, color= "red")
#
# NameError: name 'world_nopoles' is not defined
